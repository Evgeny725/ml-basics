# %%
# Задание 1.
# Написать программу, которая получает на вход строку и возвращает словарь, где:
# ключи — символы из этой строки;
# значения — количество раз, сколько каждый символ встречается.

input_string = input('enter a string to create a dictionary')
print(f'input string is {input_string}')
dict_from_string = dict

dict_from_string = {char: input_string.count(char) for char in input_string}



print(f' dict_from_string {type(dict_from_string)}')
print(f' result dictionary: \n{dict_from_string}')
# Out:
# input string is 1dd2wwww11A
#  dict_from_string <class 'dict'>
#  result dictionary:
# {'1': 3, 'd': 2, '2': 1, 'w': 4, 'A': 1}

# %%
# Задание 2.
#
# Дана строка текста (или введённая через консоль). Программа должна вернуть новую строку, в которой порядок слов будет обратным.
# Пример:
# "Python is really cool" → "cool really is Python".

# constants
separators = {' ', '.', ','}
print(f'separators: {type(separators)}')

input_text = input('enter your text to reverse the words')
word = ''
word_list = []

print(f'input text: "{input_text}"')

for char in input_text:
    if char in separators:
        if word != '':
            word_list.append(str(word))
            word = ''
    else:
        word = word + char

# last word check:
if word != '':
    word_list.append(str(word))

print(f'input word list: {word_list} \n---')
print(f'reverse word list: {word_list[::-1]}')
# Out:
# separators: <class 'set'>
# input text: "   qwe  wer,ert .rty"
# input word list: ['qwe', 'wer', 'ert', 'rty']
# ---
# reverse word list: ['rty', 'ert', 'wer', 'qwe']

# %%
# Задание 4.
#
# Написать программу, которая удаляет из списка все дубликаты, сохранив исходный порядок элементов

test_list = ['qwe', 'wer', 'ert', 'qwe', 'rty', 'qwe', 'wer']

dict_test = dict.fromkeys(test_list)

print(test_list)
print(dict_test)

test_list = [key for key in dict_test.keys()]
print(f'{test_list} - no duplicates')
# Out:
# ['qwe', 'wer', 'ert', 'qwe', 'rty', 'qwe', 'wer']
# {'qwe': None, 'wer': None, 'ert': None, 'rty': None}
# ['qwe', 'wer', 'ert', 'rty'] - no duplicates

# %%
# Задание 4.
#
# Даны три (или больше) списка с объектами. Программа должна создать новый список, содержащий все уникальные элементы — каждый объект встречается только один раз.

list_1 = ['q', 'w', 'e', 'q', 'r', 'q', 'w']
list_2 = ['a', 's', 'd', 'f', 'e', 'q', 'r']
list_3 = ['1', '2', '3', '4', '5', '6', '7']
list_4 = ['3', 'a', 'q', 'e', '1', 'c', 'b']

aggregated_dict = dict.fromkeys(list_1 + list_2 + list_3 + list_4)
print(aggregated_dict)

result_list = [key for key in aggregated_dict.keys()]
print(f'{result_list} - no duplicates')
# Out:
# {'q': None, 'w': None, 'e': None, 'r': None, 'a': None, 's': None, 'd': None, 'f': None, '1': None, '2': None, '3': None, '4': None, '5': None, '6': None, '7': None, 'c': None, 'b': None}
# ['q', 'w', 'e', 'r', 'a', 's', 'd', 'f', '1', '2', '3', '4', '5', '6', '7', 'c', 'b'] - no duplicates

# %%
# Задание 5.
# # Дана строка текста (или введённая через консоль). Программа должна вернуть словарь с четырьмя ключами:
# "гласные",
# "согласные",
# "цифры",
# "пунктуация".
# Значения — количество символов каждого типа в строке.

input_text = 'фывапр12345:";235длора5!ячсмячсмкун123'

glasnie = 'аоэеиыуёюяАОЭЕИЫУЁЮЯ'
soglasnie = 'бвгджзйклмнпрстфхцчшщБВГДЖЗЙКЛМНПРСТФХЦЧШЩ'
numbers = '0123456789'
punctuation = '.,;- :!?"'

glas_count = int()
soglas_count = int()
numbers_count = int()
punctuation_count = int()

dict_result = dict

for char in input_text:
    if char in glasnie:
        glas_count += 1
    elif char in soglasnie:
        soglas_count += 1
    elif char in numbers:
        numbers_count += 1
    elif char in punctuation:
        punctuation_count += 1

#print(glas_count, soglas_count, numbers_count, punctuation_count)
dict_result = {'гласные': glas_count, 'согласные': soglas_count, 'цифры': numbers_count, 'пунктуация': punctuation_count}

print(dict_result)
# Out:
# 7 15 12 4
# {'glasn': 7, 'согласные': 15, 'цифры': 12, 'пунктуация': 4}
