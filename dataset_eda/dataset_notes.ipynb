# %% [markdown]
# ### kaggle datasets
#
# Bank Churn Dataset Classification  (LightGBM)
# https://www.kaggle.com/code/aspillai/bank-churn-dataset-classification-lightgbm/input
#
# columns: [id,CustomerId,Surname,CreditScore,Geography,Gender,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Exited]
#
# rows: 165 000
#
# target: "exited" - marked
#
# ---
#
# Bank Marketing Dataset Full
# https://www.kaggle.com/datasets/sushant097/bank-marketing-dataset-full
#
# columns: ["age";"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome"]
#
# rows: 45 200
#
# target: no marked target column
#
#
# ---
